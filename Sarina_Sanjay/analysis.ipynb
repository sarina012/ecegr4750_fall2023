# %%
from networks import SimpleCNN
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from dataloader import CustomDataloader, NeuralNetworkData, CustomImageDataset
from networks import LinearRegressionModel
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# # Model 1 - Classic Model Analysis

# %%
# Load the data
linear_regression_training_losses = torch.load('training_model_one.pt')
linear_regression_validation_losses = torch.load('validation_model_one.pt')

# predicted_age_model_one = torch.load('predicted_age_model_one.pt')
# actual_age_model_one = torch.load('actual_age_model_one.pt')

# %%
# Plotting
plt.figure(0)
plt.plot(linear_regression_training_losses)
plt.plot(linear_regression_validation_losses)
plt.title('Model 1 - Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')

# %%
#Numerical Analysis
mse = mean_squared_error(actual_age_model_one, predicted_age_model_one)
rmse = np.sqrt(mse)
mae = mean_absolute_error (actual_age_model_one, predicted_age_model_one)
r2 = r2_score (actual_age_model_one, predicted_age_model_one)

print(f'CNN MSE: {mse}')
print(f'CNN RMSE: {rmse}')
print(f'CNN MAE: {mae}')
print(f'CNN R-Squared: {r2}')

# %% [markdown]
# # Model 2 - Neural Network Analysis

# %%
# Load the data
cnn_regression_training_losses = torch.load('training_model_two.pt')
cnn_regression_validation_losses = torch.load('validation_model_two.pt')
predicted_age_model_two = torch.load('predicted_age_model_two.pt')
actual_age_model_two = torch.load('actual_age_model_two.pt')

# %%
#Numerical Analysis
mse = mean_squared_error(actual_age_model_two, predicted_age_model_two)
rmse = np.sqrt(mse)
mae = mean_absolute_error (actual_age_model_two, predicted_age_model_two)
r2 = r2_score (actual_age_model_two, predicted_age_model_two)

print(f'CNN MSE: {mse}')
print(f'CNN RMSE: {rmse}')
print(f'CNN MAE: {mae}')
print(f'CNN R-Squared: {r2}')
# Out:
# CNN MSE: 134.77335662219627
# CNN RMSE: 11.609192763590253
# CNN MAE: 8.380070102742955
# CNN R-Squared: 0.6544419439421467

# %%
# Plotting
plt.figure(0)
plt.plot(cnn_regression_training_losses)
plt.plot(cnn_regression_validation_losses)
plt.title('Model 2 - Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')

# %% [markdown]
# # Model 3 - Multimodal Neural Network Analysis

# %%
# Load the data
multimodal_regression_training_losses = torch.load('training_model_two.pt')
multimodal_regression_validation_losses = torch.load('validation_model_two.pt')
predicted_age_model_three = torch.load('predicted_age_model_two.pt')
actual_age_model_three = torch.load('actual_age_model_two.pt')

# %%
#Numerical Analysis
mse = mean_squared_error(actual_age_model_three, predicted_age_model_three)
rmse = np.sqrt(mse)
mae = mean_absolute_error (actual_age_model_three, predicted_age_model_three)
r2 = r2_score (actual_age_model_three, predicted_age_model_three)

print(f'CNN MSE: {mse}')
print(f'CNN RMSE: {rmse}')
print(f'CNN MAE: {mae}')
print(f'CNN R-Squared: {r2}')
# Out:
# CNN MSE: 134.77335662219627
# CNN RMSE: 11.609192763590253
# CNN MAE: 8.380070102742955
# CNN R-Squared: 0.6544419439421467

# %%
# Plotting
plt.figure(0)
plt.plot(multimodal_regression_training_losses)
plt.plot(multimodal_regression_validation_losses)
plt.title('Model 3 - Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
